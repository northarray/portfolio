# %%
#| default_exp util

# %% [markdown]
# # util

# %%
#| export
from pathlib import Path

# %%
#| export
def data_path():
    import portfolio
    return Path(portfolio.__file__).parent.parent/'data'
