# %%
#| hide
from portfolio.core import *
from portfolio.sample_data import *

# %% [markdown]
# # portfolio
#
# >

# %% [markdown]
# Tool for simulating, comparing and visualising the performance of investment portfolios.

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/northarray/portfolio.git
# ```
#
#
#
# [repo]: https://github.com/northarray/portfolio
# [docs]: https://northarray.github.io/portfolio/

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs].
#
# [repo]: https://github.com/northarray/portfolio
# [docs]: https://northarray.github.io/portfolio/

# %% [markdown]
# ## How to use

# %% [markdown]
# Check out core module for full usage. The main idea is that a portfolio consists of monthly return streams together with a weighing scheme. Here is a quick intro:

# %%
rets, rf, cpi = sample_data_se()

# %%
p = Portfolio('60/40', rets, {'bonds': .40, 'stocks': .60}, rf=rf, cpi=cpi)
p
# Out:
# {'bonds': 0.4, 'stocks': 0.6}

# %%
p.stats()
# Out:
# expected_return    0.055278
# volatility         0.112835
# sharpe_ratio       0.489897
# Name: 60/40, dtype: float64

# %%
p.real_w().head()
# Out:
# 1955-02    1.001710
# 1955-03    1.010626
# 1955-04    0.983135
# 1955-05    0.959486
# 1955-06    0.945793
# Freq: M, Name: 60/40, dtype: float64

# %%
p.real_w().plot(logy=True)
# Out:
# <Axes: >
