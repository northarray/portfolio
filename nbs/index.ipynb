# %%
#| hide
#from portfolio.core import *

# %% [markdown]
# # portfolio
#
# >

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install portfolio in Development mode

# %% [markdown]
# ```sh
# # make sure portfolio package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to portfolio
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/northarray/portfolio.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c northarray portfolio
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install portfolio
# ```
#
#
# [repo]: https://github.com/northarray/portfolio
# [docs]: https://northarray.github.io/portfolio/
# [pypi]: https://pypi.org/project/portfolio/
# [conda]: https://anaconda.org/northarray/portfolio

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/northarray/portfolio
# [docs]: https://northarray.github.io/portfolio/
# [pypi]: https://pypi.org/project/portfolio/
# [conda]: https://anaconda.org/northarray/portfolio

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
